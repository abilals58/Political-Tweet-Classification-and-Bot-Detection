# %%
with open('politicalParties.txt') as f:
    lines = f.readlines()

partyMembers = []
partyMembersTwitter = []
for line in lines:
    partyMembers.append(line.split(",")[0])
    temp = (line.split(",")[4].split("twitter.com"))[-1]
    if temp[0] == '/':
        partyMembersTwitter.append(temp[1:-1])
    
print(partyMembersTwitter)
# Out:
# ['RTErdogan', 'BY', 'NumanKurtulmus', 'Hayati_Yazici', 'erkankandemir', 'aliihsanyavuz54', 'avhamzadag', 'efkanala', 'jsarieroglu', 'mehmetozhaseki', 'nurettincanikli', 'AvOzlemZengin', 'leylasahinusta', 'vedatdemiroz', 'DrOmerileri', 'omerrcelik', '_fatihsahin', 'aysekesir', 'eyupkadirinan', 'kilicdarogluk', 'ali_oztunc', 'bkusoglu', 'bulenttezcanchp', 'faikoztrak', 'gamzeilgezdi', 'GokceGokcen_', 'GulizarBicer', 'lalekarabiyik', 'muharremerkek17', 'oguzksalici', 'onursaladiguzel', 'selinsayekboke', 'seyit_torun', 'yukseltaskinn', 'alibabacan', 'birolaydemir15', 'yaseminbilgel1', 'bdalgin', 'emin_ekmen', 'mustafaergen_', 'erginsadullah', 'elifesendeva', 'helunfirat', 'hasankaraltr', 'c_karlitekin', 'sanemoktar', 'hatipoglupaysun', 'rizvanogluevrim', 'avidrissahin', 'dogasanlioglu', 'mustafaucak07', 'nazlisedavural', 'myeneroglu', 'medeniylmz', 'Ahmet_Davutoglu', 'mnedimyamali', 'SelimTemurci', 'AyhanSeferUSTUN', 'dogandemir41', 'FeridunBilgin64', 'selcukozdag', 'abdullahbasci', 'ker
# ...

# %%
with open('party_affiliated_others.txt') as f:
    lines = f.readlines()

partyMembers = []
partyMembersTwitter = []
for line in lines:
    partyMembers.append(line.split(",")[0])
    partyMembersTwitter.append(line.split(",")[1])
    
print(partyMembersTwitter)
# Out:
# ['Twitter', '06melihgokcek', 'meral_aksener', 'osmannnurika', 'akaraismailoglu', 'varank', 'fahrettinaltun', 'deryayanikashb', 'ayyildirim1', 'RTErdogan', 'mansuryavas06', 'ekrem_imamoglu', 'fuatoktay', 'FatmaSahin', 'drfahrettinkoca', 'ikalin1', 'Canan_Kaftanci', 'tuncsoyer']

# %%
import string
import operator
import gzip
import json
import numpy as np
import pandas as pd

i = 0
totalTweets = 0
uniqueWords = {}

with gzip.open("data/user_tweets.jsons.gz", "rb") as f:
    for line in f:

        line = json.loads(line)
        
        for tweet in line['tweets']:
            totalTweets += 1
            words = (tweet['text'].split())
            for word in words:
                unique_word = word.lower().translate(str.maketrans('', '', string.punctuation))
                if unique_word not in uniqueWords.keys():
                    uniqueWords[unique_word] = 1
                else:
                    uniqueWords[unique_word] += 1

        i += 1
        if i % 100 == 0:
            print(i)
            
sortedUniqueWords = dict(sorted(uniqueWords.items(), key=operator.itemgetter(1), reverse=True))

uniqueWordsDf = pd.DataFrame.from_dict(sortedUniqueWords, orient ='index')

print("\nTotal Tweets:")
print(totalTweets)

uniqueWordsDf
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
sortedUniqueWords
# Out:
# {'rt': 1964616,
#  've': 662510,
#  'bir': 645538,
#  'bu': 511867,
#  '': 366022,
#  'rterdogan': 273765,
#  'için': 273756,
#  'de': 245101,
#  'ne': 233752,
#  'çok': 205426,
#  'da': 195288,
#  'ile': 182906,
#  'var': 155788,
#  'her': 154064,
#  'o': 145162,
#  'en': 139940,
#  'kadar': 137409,
#  'sayın': 132769,
#  'olsun': 131561,
#  'daha': 129241,
#  'yok': 127327,
#  'ama': 120195,
#  'gibi': 118243,
#  'olarak': 117082,
#  'olan': 111596,
#  'değil': 107227,
#  'ben': 104884,
#  'ya': 99989,
#  'ki': 96886,
#  'mi': 95605,
#  'biz': 91253,
#  'sen': 86583,
#  'bin': 86343,
#  'atama': 80403,
#  'diye': 79174,
#  'artık': 76153,
#  'drfahrettinkoca': 75384,
#  'güzel': 71465,
#  'allah': 69664,
#  'türkiye': 68903,
#  'mı': 66361,
#  'tüm': 65312,
#  'iyi': 64351,
#  'genel': 63693,
#  'sonra': 63675,
#  'son': 62343,
#  '1': 61623,
#  'bugün': 60963,
#  'büyük': 60794,
#  'bi': 59910,
#  'yeni': 59119,
#  'zaman': 58561,
#  'the': 58420,
#  'bile': 58380,
# ...

# %%
political_users = ['06melihgokcek', '_cevdetyilmaz', '_fatihsahin', 'abdulhamitgul', 'abdullahbasci', 'adem__taskaya', 'aefakibaba', 'ahmet_davutoglu', 'ahmet_erozan', 'ahmetedip_ugur', 'akaraismailoglu', 'akburak', 'akgencistanbul', 'akgenclikgm', 'akkadingm', 'akparti', 'ali_oztunc', 'alibabacan', 'alidincercolak', 'aliihsanyavuz54', 'alipulcu', 'av_ebrugunay', 'avhamzadag', 'avidrissahin', 'avozlemzengin', 'avtolgaakalin', 'avunzileyuksel', 'ayangurol', 'ayhanseferustun', 'ayhanturkz', 'ayseacar_b', 'aysekesir', 'ayyildirim1', 'bakanguler', 'bartusoral', 'bayirfikret', 'bbahadirerdem', 'bbbozarslan', 'bdalgin', 'bekirpakdemirli', 'birolaydemir15', 'birolaydinsp', 'bkusoglu', 'bmustafagozel', 'bulent_arinc', 'bulenttezcanchp', 'buyukataman', 'by', 'bybekirbozdag', 'c_karlitekin', 'canan_kaftanci', 'cezmi_polat', 'chpgencistanbul', 'chpgenclikgm', 'ck_samsun', 'csgbakanligi', 'csgbfarukcelik', 'dbdevletbahceli', 'deryayanikashb', 'dogandemir41', 'dogasanlioglu', 'dr_demircan', 'draslanyaman', 'drfahrettinkoca', 'dromerileri', 'drsametmenguc', 'e_semihyalcin', 'eczozgurozel', 'efkanala', 'egemenbagis', 'ekrem_imamoglu', 'elifesendeva', 'emin_ekmen', 'emniyetankara', 'emniyetgm', 'erdoganbayraktr', 'erginsadullah', 'erkankandemir', 'eyupkadirinan', 'fahrettinaltun', 'faikoztrak', 'fatmasahin', 'fatmasahin_aspb', 'feleknasuca', 'feramuzustun', 'feridunbilgin64', 'feridunyildiz', 'figenyuksekdag', 'fuatoktay', 'gamzeilgezdi', 'garopaylan', 'gazianteppolis', 'gokcegokcen_', 'guleryuzmahfuz', 'gulizarbicer', 'hakan_cavusoglu', 'hasankaraltr', 'hatipoglupaysun', 'hbb_ciftcioglu', 'hdpdemirtas', 'helunfirat', 'herkesicinchp', 'ifarukaksu', 'ikalin1', 'ilknur_birol', 'ismail_turk55', 'istanbul_egm', 'jsarieroglu', 'kadir_topbas', 'kamilaydinmhp', 'kaptmustafacan', 'karakayamevlut', 'kartalakgenclik', 'kasapoglu', 'kerimrota', 'kilicdarogluk', 'kocaeliemniyeti', 'kocaktukenmez', 'korayaydintr', 'lalekarabiyik', 'leylasahinusta', 'lutfusahsuvar', 'mahirunal', 'mansuryavas06', 'medeniylmz', 'mehmetozhaseki', 'memetsimsek', 'meral_aksener', 'meraldanis', 'metinergun48', 'mevlutcavusoglu', 'mhp_bilgi', 'mithatsancarr', 'mnedimyamali', 'muezzinogludr', 'muharremerkek17', 'murat_kurum', 'muratozgur2001', 'musaproglu', 'mustafaergen_', 'mustafamente', 'mustafasentop', 'mustafaucak07', 'myeneroglu', 'nazlisedavural', 'numankurtulmus', 'nureddinnebati', 'nurettincanikli', 'oguzksalici', 'omerrcelik', 'onursaladiguzel', 'osmannnurika', 'pekcan', 'pervinbuldan', 'prfdrfilizkilic', 'profbilgeyilmaz', 'ridvanuz17', 'rizvanogluevrim', 'rterdogan', 'saadethukuk', 'saadetpartisi', 'sadirdurmaz', 'sagaltun', 'saglikbakanligi', 'salimensarioglu', 'sanemoktar', 'saruhanoluc', 'saziyekose59', 'sedattimur161', 'selcukozdag', 'selimtemurci', 'selinsayekboke', 'semasilkin', 'senolsunat', 'serapprof', 'serkanozcan1', 'sevdagultuncer', 'sevincatabay', 'seyit_torun', 'seyityucel06', 'sonmeznaci', 'suatkilic', 'suleymansoyluhayati_yazici', 'sultanozcan38', 't_karamollaoglu', 'tayiptemel', 'tc_disisleri', 'tc_icisleri', 'tcbestepe', 'tckayalak', 'tcmeb', 'tcsavunma', 'tmrosmanagaoglu', 'torunkani', 'tugrulk_zaferp', 'tuncerbakirhan', 'tuncsoyer', 'ugur__poyraz', 'ugurbaturr', 'ulviyonter', 'umitdikbayir', 'umitozdag', 'umitozlale', 'umityardim1961', 'umutdede16', 'varank', 'vedatbilgn', 'vedatdemiroz', 'vekilince', 'velisacilik', 'veyseleroglu', 'yasaryldrmmhp', 'yaseminbilgel1', 'yildizfeti', 'yukseltaskinn', 'yunusparim']
political_users = (sorted(list(set(political_users))))
print(political_users)
# Out:
# ['06melihgokcek', '_cevdetyilmaz', '_fatihsahin', 'abdulhamitgul', 'abdullahbasci', 'adem__taskaya', 'aefakibaba', 'ahmet_davutoglu', 'ahmet_erozan', 'ahmetedip_ugur', 'akaraismailoglu', 'akburak', 'akgencistanbul', 'akgenclikgm', 'akkadingm', 'akparti', 'ali_oztunc', 'alibabacan', 'alidincercolak', 'aliihsanyavuz54', 'alipulcu', 'av_ebrugunay', 'avhamzadag', 'avidrissahin', 'avozlemzengin', 'avtolgaakalin', 'avunzileyuksel', 'ayangurol', 'ayhanseferustun', 'ayhanturkz', 'ayseacar_b', 'aysekesir', 'ayyildirim1', 'bakanguler', 'bartusoral', 'bayirfikret', 'bbahadirerdem', 'bbbozarslan', 'bdalgin', 'bekirpakdemirli', 'birolaydemir15', 'birolaydinsp', 'bkusoglu', 'bmustafagozel', 'bulent_arinc', 'bulenttezcanchp', 'buyukataman', 'by', 'bybekirbozdag', 'c_karlitekin', 'canan_kaftanci', 'cezmi_polat', 'chpgencistanbul', 'chpgenclikgm', 'ck_samsun', 'csgbakanligi', 'csgbfarukcelik', 'dbdevletbahceli', 'deryayanikashb', 'dogandemir41', 'dogasanlioglu', 'dr_demircan', 'draslanyaman', 'drfahr
# ...

# %%
political_keywords = ['100yılaffı', 'adalet', 'adaletaffı', 'adil', 'ak parti', 'akp', 'akparti', 'atama', 'atamaları', 'ataması', 'atamavakti', 'babacan', 'bakanlık', 'bakanlığı', 'başkan', 'başkanlık', 'başkanı', 'başkanım', 'başkanımız', 'belediye', 'belediyesi', 'büyükşehir', 'chp', 'chpli', 'cumhurbaşkanlığı', 'cumhurbaşkanı', 'cumhurbaşkanım', 'cumhurbaşkanımız', 'cumhuriyet', 'cumhuriyetçi', 'deva', 'ekonomi', 'enflasyon', 'erdoğan', 'eyt', 'eşitlik', 'fetö', 'güvenlik', 'hakları', 'hdp', 'hukuk', 'ibb', 'imamoğlu', 'ittifakı', 'kadro', 'khk', 'kılıçdaroğlu', 'mahkeme', 'mağdur', 'mhp', 'milletvekili', 'oy', 'parti', 'partisi', 'pkk', 'recep', 'reis', 'reisimiz', 'sayın', 'sağlık', 'seçim', 'siyaset', 'sn', 'soylu', 'soysuz', 'tayyip', 'taşeron', 'terör', 'terörist', 'uzmançavuşlarakadro', 'özgürlük', 'şanınayakışır', 'şartlıeytyehayır']
political_keywords = (sorted(list(set(political_keywords))))
print(political_keywords)
# Out:
# ['100yılaffı', 'adalet', 'adaletaffı', 'adil', 'ak parti', 'akp', 'akparti', 'atama', 'atamaları', 'ataması', 'atamavakti', 'babacan', 'bakanlık', 'bakanlığı', 'başkan', 'başkanlık', 'başkanı', 'başkanım', 'başkanımız', 'belediye', 'belediyesi', 'büyükşehir', 'chp', 'chpli', 'cumhurbaşkanlığı', 'cumhurbaşkanı', 'cumhurbaşkanım', 'cumhurbaşkanımız', 'cumhuriyet', 'cumhuriyetçi', 'deva', 'ekonomi', 'enflasyon', 'erdoğan', 'eyt', 'eşitlik', 'fetö', 'güvenlik', 'hakları', 'hdp', 'hukuk', 'ibb', 'imamoğlu', 'ittifakı', 'kadro', 'khk', 'kılıçdaroğlu', 'mahkeme', 'mağdur', 'mhp', 'milletvekili', 'oy', 'parti', 'partisi', 'pkk', 'recep', 'reis', 'reisimiz', 'sayın', 'sağlık', 'seçim', 'siyaset', 'sn', 'soylu', 'soysuz', 'tayyip', 'taşeron', 'terör', 'terörist', 'uzmançavuşlarakadro', 'özgürlük', 'şanınayakışır', 'şartlıeytyehayır']

# %%
zort = "merhaba. benim adım_emir değil senin adın nedir bilmiyorum!* haha:) @halperk adresinde #burası xD!!"
# new_string = zort.translate(str.maketrans('', '', string.punctuation))
new_string = zort.translate(str.maketrans('', '', "!\"$%&'()*+,-./:;<=>?[\]^`{|}~"))
print(new_string)
# Out:
# merhaba benim adım_emir değil senin adın nedir bilmiyorum haha @halperk adresinde #burası xD

# %%
import string
import operator
import gzip
import json
import numpy as np
import pandas as pd

i = 0
totalTweets = 0
uniqueHashtags = {}
uniqueMentions = {}

with gzip.open("data/user_tweets.jsons.gz", "rb") as f:
    for line in f:

        line = json.loads(line)
        
        for tweet in line['tweets']:
            totalTweets += 1

            if len(tweet['entities']) != 0:
                if len(tweet['entities']['hashtags']) != 0:
                    hashtags = tweet['entities']['hashtags']
                    for hashtag in hashtags:
                        hashtag = hashtag['text']
                        if hashtag not in uniqueHashtags.keys():
                            uniqueHashtags[hashtag] = 1
                        else:
                            uniqueHashtags[hashtag] += 1
                if len(tweet['entities']['user_mentions']) != 0:
                    mentions = tweet['entities']['user_mentions']
                    for mention in mentions:
                        mention = mention['screen_name']
                        if mention not in uniqueMentions.keys():
                            uniqueMentions[mention] = 1
                        else:
                            uniqueMentions[mention] += 1
        
        i += 1
        if i % 100 == 0:
            print(i)
            
sortedUniqueHashtags = dict(sorted(uniqueHashtags.items(), key=operator.itemgetter(1), reverse=True))
sortedUniqueMentions = dict(sorted(uniqueMentions.items(), key=operator.itemgetter(1), reverse=True))

print("\nTotal Tweets:")
print(totalTweets)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
sortedUniqueHashtags
# Out:
# {'İçişleriYedeklerAtansın': 8743,
#  'GenelAf': 8315,
#  'ŞartlıEYTyeHayır': 7537,
#  'UzmanÇavuşlaraKadro': 7316,
#  'CumhurÜcretliÖgrtKadro': 5967,
#  'EhliyetAffı': 5286,
#  'KamuŞefleri': 5216,
#  'StajyerinSelamıVar': 5152,
#  'Bütçeden100binÖğretmen': 5018,
#  'SONDAKİKA': 4654,
#  'MedyaStajDemeyeGel': 4526,
#  '112AÇMyeAcilÇmhAlımı': 4110,
#  '2023YolundaBiriz': 4103,
#  'TaşeronunAdaletiYoktur': 3752,
#  'EYT': 3621,
#  'YüzbinÖğretmeninSesi': 3237,
#  'KIZILELMA': 3230,
#  'BakanÖzerAtamaNerede': 3018,
#  'TOGG': 2919,
#  'StajSskBaşlangıcıOlsun': 2903,
#  'TaşerondaAdaletliOlun': 2875,
#  'YineGeleceğiz': 2748,
#  '21YüzyıldaTaşeronOlmasın': 2735,
#  'Erdoğandan100BinÖğretmen': 2429,
#  'StajaAdalet': 2405,
#  'KurtulmAKistiyoruz': 2401,
#  'deprem': 2303,
#  'CanlıYayın': 2297,
#  'TBMM': 2256,
#  'AzKaldı': 2129,
#  'KılıçdaroğluNeSöyledi': 2072,
#  'HerBranşaAdilAtama': 2036,
#  'BakanÖzeristifa': 1976,
#  'NotereSözVatanaCanVerdik': 1955,
# ...

# %%
import locale
locale.setlocale(locale.LC_ALL, 'tr_TR.utf8')
# political_hashtags = ['İçişleriYedeklerAtansın', 'GenelAf', 'ŞartlıEYTyeHayır', 'UzmanÇavuşlaraKadro', 'CumhurÜcretliÖgrtKadro', 'EhliyetAffı', 'StajyerinSelamıVar', 'Bütçeden100binÖğretmen', '112AÇMyeAcilÇmhAlımı', '2023YolundaBiriz', 'EYT', 'YüzbinÖğretmeninSesi', 'StajSskBaşlangıcıOlsun', 'TaşerondaAdaletliOlun', '21YüzyıldaTaşeronOlmasın', 'Erdoğandan100BinÖğretmen', 'StajaAdalet', 'KurtulmAKistiyoruz', 'KılıçdaroğluNeSöyledi', 'AralıkSonuŞartsızEYT', 'GeleceğizYineGeleceğiz', 'TürkiyeYüzyılı', 'ŞehadetEsasKadroHaktır', 'KabinedeTaşerondaOlsun', 'EYTlininSabrıTaştı', 'BelediyeŞirketiKadroya', 'Ziraate15Bin6liMasa', 'EYTdeYaşKoşulunaHayır','ElektrikElektronikMüh3binKadro', 'TarikatveCemaatlerKapatılsın', 'TCYüzyılıÜcretliÖgrtKadro', 'UzmanÇavuşlarKadroya', 'BütcedeTaşeronVarmı', 'KamudaKadrosuzKalmasın', 'LiseTıbbiSekretere0Kadro', 'KamuİşçisiKadrosuzKalmasın', 'TaşeronaŞartsızKadro', 'BenimOyum100BinAtamaya', '112AçmyeÇmhdenAlım', 'ÖgretmeneEnAz25Bin', 'Kasıma100BinÖğretmen', 'SonSözüEYTSöyler', 'ÖzdağaDokunma', 'SıradaStajOlsun', 'VeterinerHekimler5000Atamaİstiyor', 'YüzyılınAtaması24Kasımda', '10BinKadro', 'AmerikanınÇocuklarısınız', 'CB15BinZiraatMüh', 'EhliyetAffi', 'Bütçeden100BinÖğretmen', 'MemurÖgrtVerimliİstihdam', 'KapımaGelmeOyİçin', 'İkinciYüzyılaÇağrı', '112ÇMHyeTekTercihYetersiz', 'KgmMüşavireKadroHaktır', 'TBMMvekilimamlaraKadro', 'KasımdaAdil100BinAtama', '10AralıkDünyaİnsanHaklarıGünü', 'ZorunluEmeklilikKaldırılsın', 'imarbarışıgüncellensin', 'EmeklilikteYaşaTakılanlar', 'GeliyorGelmekteOlan', 'SağlıSolluTokatlaSOYLU', 'BağkurTescilMağdurları', 'StajSskBaslangiciOlsun', 'SağlığaVarÖğretmeneYok', 'EngelliyeAtamaMüjdesi', 'ÜmitÖzdağ', 'VergideAdaletBelediyedeKadro', 'TaşeronunSabrıKalmadı', 'KadroİçinMeclise', '120binTaşeronBekliyor', 'ÖğretmeneEnAz25Bin', 'TaşeronRadyolojiKadroBekliyor', 'TaşeronTorbaya', 'TaşeronNedenBekliyor', 'PatronSağlıkBakanıİstemiyoruz', 'KasapogluDestekVer', 'StajyerMuhalefetDiyor', 'KimlerTaşeronİşçisi', 'KabineSözlmYeKadro', 'TaşeronMecliseGelmeli', 'zorunluemeklilikzulümdür', 'AralıktaKadroOcaktaEş', 'Dib15BinAlımHakkımız', '112AÇMyeOrtaksızAlım', 'SözleşmeliMemuraŞartsızKadro', 'ogretmenlersusmayacak', 'şehirhastanelerinekadro', 'TaşeronUcubeBirSistemdir', 'KıslasızMakulBedelli', 'MüjdeZamanıGelmediMi', 'Yanındayızİmamoğlu', 'Diyetisyen245eKarşı', 'ÖğretmeneYüzde100Zam', 'VatanSavunanaKadro', 'Ehliyetaffı', 'HerkeseKadroUzmÇvşaYokmu', 'pomemeyedekcagri', 'TümTaşeronlaraKadro', 'ehliyetaffı', 'EytDepremMağdurları', '112AÇMÇmhİleDahaGüçlü', 'MebLiseGeneliAf', 'StajYoksaOydaYok', 'lisetıbbisekretere0kadro', 'KadroHaktır', 'SartlıEYTyeHayır', 'EmeklilkteYasaTakılanlar', 'TarikatveCemaatlerKAPATILSIN', 'SansürYasasınaHayır', 'YüzüncüYıla100binAtama', 'Eyt99SonuHakkımız', 'Kgm1000Atama', 'önlisanssosyalgüvenlik4binatama', 'KadroVekilİmamlarınHakkı', 'EmekleriYasalaraTakılanlar', 'CBingilizce10binatama', '5BinAtamaRadyolojiye', '2000SonrasıSgklıAdaletİstiyor', 'CumhurÜcretliÖğrtKadro', 'AtamaYapmaÖnLisansıBekle', 'güvenlikkorucularınsesiniduyun']
# for i in range(len(political_hashtags)):
#     political_hashtags[i] = political_hashtags[i].lower()

political_hashtags = ['10aralıkdünyainsanhaklarıgünü', '10binkadro', '100yılaffı', '112açmyeacilçmhalımı', '112açmyeortaksızalım', '112açmyeçmhdenalım', '112açmçmhiledahagüçlü', '112çmhyetektercihyetersiz', '120bintaşeronbekliyor', '2000sonrasısgklıadaletistiyor', '2023yolundabiriz', '21yüzyıldataşeronolmasın', '5binatamaradyolojiye', 'adaletaffı', 'amerikanınçocuklarısınız', 'aralıksonuşartsızeyt', 'aralıktakadroocaktaeş', 'atamayapmaönlisansıbekle', 'bağkurtescilmağdurları', 'belediyeşirketikadroya', 'benimoyum100binatamaya', 'bütcedetaşeronvarmı', 'bütçeden100binöğretmen', 'cb15binziraatmüh', 'cbingilizce10binatama', 'cumhurücretliögrtkadro', 'cumhurücretliöğrtkadro', 'dib15binalımhakkımız', 'diyetisyen245ekarşı', 'ehliyetaffi', 'ehliyetaffı', 'elektrikelektronikmüh3binkadro', 'emekleriyasalaratakılanlar', 'emeklilikteyaşatakılanlar', 'emeklilkteyasatakılanlar', 'engelliyeatamamüjdesi', 'erdoğandan100binöğretmen', 'eyt', 'eyt99sonuhakkımız', 'eytdepremmağdurları', 'eytdeyaşkoşulunahayır', 'eytlininsabrıtaştı', 'geleceğizyinegeleceğiz', 'geliyorgelmekteolan', 'genelaf', 'güvenlikkorucularınsesiniduyun', 'herkesekadrouzmçvşayokmu', 'imarbarışıgüncellensin', 'ikinciyüzyılaçağrı', 'içişleriyedekleratansın', 'kabinedetaşerondaolsun', 'kabinesözlmyekadro', 'kadrohaktır', 'kadroiçinmeclise', 'kadrovekili̇mamlarınhakkı', 'kamudakadrosuzkalmasın', 'kamui̇şçisikadrosuzkalmasın', 'kapımagelmeoyi̇çin', 'kasapogludestekver', 'kasıma100binöğretmen', 'kasımdaadil100binatama', 'kgm1000atama', 'kgmmüşavirekadrohaktır', 'kimlertaşeronişçisi', 'kurtulmakistiyoruz', 'kılıçdaroğlunesöyledi', 'kıslasızmakulbedelli', 'lisetıbbisekretere0kadro', 'meblisegeneliaf', 'memurögrtverimliistihdam', 'müjdezamanıgelmedimi', 'ogretmenlersusmayacak', 'patronsağlıkbakanıi̇stemiyoruz', 'pomemeyedekcagri', 'sansüryasasınahayır', 'sartlıeytyehayır', 'sağlısollutokatlasoylu', 'sağlığavaröğretmeneyok', 'sonsözüeytsöyler', 'stajaadalet', 'stajsskbaslangiciolsun', 'stajsskbaşlangıcıolsun', 'stajyerinselamıvar', 'stajyermuhalefetdiyor', 'stajyoksaoydayok', 'sözleşmelimemuraşartsızkadro', 'sıradastajolsun', 'tarikatvecemaatlerkapatilsin', 'tarikatvecemaatlerkapatılsın', 'taşeronaşartsızkadro', 'taşerondaadaletliolun', 'taşeronmeclisegelmeli', 'taşeronnedenbekliyor', 'taşeronradyolojikadrobekliyor', 'taşerontorbaya', 'taşeronucubebirsistemdir', 'taşeronunsabrıkalmadı', 'tbmmvekilimamlarakadro', 'tcyüzyılıücretliögrtkadro', 'tümtaşeronlarakadro', 'türkiyeyüzyılı', 'uzmançavuşlarakadro', 'uzmançavuşlarkadroya', 'vatansavunanakadro', 'vergideadaletbelediyedekadro', 'veterinerhekimler5000atamaistiyor', 'yanındayızimamoğlu', 'yüzbinöğretmeninsesi', 'yüzyılınataması24kasımda', 'yüzüncüyıla100binatama', 'ziraate15bin6limasa', 'zorunluemeklilikkaldırılsın', 'zorunluemeklilikzulümdür', 'ögretmeneenaz25bin', 'önlisanssosyalgüvenlik4binatama', 'özdağadokunma', 'öğretmeneenaz25bin', 'öğretmeneyüzde100zam', 'ümitözdağ', 'şanınayakışır', 'şartlıeytyehayır', 'şartlıeytyehayır', 'şehadetesaskadrohaktır', 'şehirhastanelerinekadro']
political_hashtags = (sorted(list(set(political_hashtags))))
print(political_hashtags)
# Out:
# ['10aralıkdünyai̇nsanhaklarıgünü', '10binkadro', '112açmyeacilçmhalımı', '112açmyeortaksızalım', '112açmyeçmhdenalım', '112açmçmhi̇ledahagüçlü', '112çmhyetektercihyetersiz', '120bintaşeronbekliyor', '2000sonrasısgklıadaleti̇stiyor', '2023yolundabiriz', '21yüzyıldataşeronolmasın', '5binatamaradyolojiye', 'amerikanınçocuklarısınız', 'aralıksonuşartsızeyt', 'aralıktakadroocaktaeş', 'atamayapmaönlisansıbekle', 'bağkurtescilmağdurları', 'belediyeşirketikadroya', 'benimoyum100binatamaya', 'bütcedetaşeronvarmı', 'bütçeden100binöğretmen', 'cb15binziraatmüh', 'cbingilizce10binatama', 'cumhurücretliögrtkadro', 'cumhurücretliöğrtkadro', 'dib15binalımhakkımız', 'diyetisyen245ekarşı', 'ehliyetaffi', 'ehliyetaffı', 'elektrikelektronikmüh3binkadro', 'emekleriyasalaratakılanlar', 'emeklilikteyaşatakılanlar', 'emeklilkteyasatakılanlar', 'engelliyeatamamüjdesi', 'erdoğandan100binöğretmen', 'eyt', 'eyt99sonuhakkımız', 'eytdepremmağdurları', 'eytdeyaşkoşulunahayır', 'eytlininsabrıtaştı', 'geleceğizyineg
# ...

# %%
sortedUniqueMentions
# Out:
# {'RTErdogan': 286543,
#  'drfahrettinkoca': 77311,
#  'vedatbilgn': 54407,
#  'suleymansoylu': 53369,
#  'kilicdarogluk': 51451,
#  'Akparti': 43811,
#  'dbdevletbahceli': 37516,
#  'meral_aksener': 33375,
#  'tcbestepe': 29848,
#  'tcmeb': 29205,
#  'umitozdag': 24312,
#  'MHP_Bilgi': 18859,
#  'aykiricomtr': 18730,
#  'ekrem_imamoglu': 17177,
#  'ozan_blk07': 17076,
#  'tele1comtr': 16333,
#  'Mustafa_Destici': 15283,
#  'fuatoktay': 15052,
#  'bybekirbozdag': 14834,
#  '06melihgokcek': 14567,
#  'VahitKirisci': 13813,
#  'deryayanikashb': 13390,
#  'osmannnurika': 13344,
#  'NureddinNebati': 12950,
#  'akaraismailoglu': 12633,
#  'csgbakanligi': 12589,
#  'varank': 11996,
#  'herkesicinCHP': 11906,
#  'BY': 11478,
#  'odatv': 11131,
#  'zekibahce': 11020,
#  'tcsavunma': 11017,
#  'halktvcomtr': 10756,
#  'AlcayirCengiz': 10339,
#  'yenisafak': 10308,
#  'DIBAliErbas': 9883,
#  'sgirgin48tbmm': 9812,
#  'arzuerdemDB': 9798,
#  'yirmiucderece': 9483,
#  'TCAytunCiray': 9436,
# ...

# %%
import csv

all_tweets = []

with open("evaluation-round2-tweet.csv", 'r') as file:
    csvreader = csv.reader(file)
    for row in csvreader:
        all_tweets.append(row[0])

print("Total Tweets:", len(all_tweets))                          
print(all_tweets)
# Out:
# Total Tweets: 5000
# ...

# %%
import csv

all_tweets = []

with open("evaluation-round2-tweet.csv", 'r') as file:
    csvreader = csv.reader(file)
    for row in csvreader:
        all_tweets.append(row[0])

        
import string
import operator
import gzip
import json
import numpy as np
import pandas as pd

i = 0
totalTweets = 0
uniqueWords = {}

with gzip.open("data/tweet_metadata.jsons.gz", "rb") as f:
    for line in f:

        tweet = json.loads(line)
        if tweet['id_str'] in all_tweets:
            print("match")
            totalTweets += 1
            words = (tweet['text'].split())
            for word in words:
                unique_word = word.lower().translate(str.maketrans('', '', string.punctuation))
                if unique_word not in uniqueWords.keys():
                    uniqueWords[unique_word] = 1
                else:
                    uniqueWords[unique_word] += 1

        i += 1
        if i % 100 == 0:
            print(i)
            
sortedUniqueWords = dict(sorted(uniqueWords.items(), key=operator.itemgetter(1), reverse=True))

uniqueWordsDf = pd.DataFrame.from_dict(sortedUniqueWords, orient ='index')

print("\nTotal Tweets:")
print(totalTweets)

uniqueWordsDf
# Out:
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# 100
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# 200
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# 300
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# 400
# ...

# %%
sortedUniqueWords
# Out:
# {'rterdogan': 662,
#  've': 517,
#  'bir': 481,
#  'bu': 465,
#  '': 284,
#  'sayın': 255,
#  'ne': 248,
#  'için': 248,
#  'kilicdarogluk': 237,
#  'de': 196,
#  'meralaksener': 195,
#  'çok': 188,
#  'drfahrettinkoca': 166,
#  'da': 164,
#  'olarak': 163,
#  'ile': 160,
#  'her': 155,
#  'suleymansoylu': 153,
#  'kadar': 147,
#  'o': 143,
#  'var': 142,
#  'atama': 138,
#  'yok': 135,
#  'daha': 133,
#  'ama': 132,
#  'biz': 132,
#  'gibi': 131,
#  'en': 131,
#  'olsun': 130,
#  'umitozdag': 123,
#  'bin': 117,
#  'kadro': 116,
#  'olan': 114,
#  'vedatbilgn': 106,
#  'değil': 105,
#  'sen': 101,
#  'mi': 100,
#  'ben': 95,
#  'ya': 94,
#  'istiyoruz': 93,
#  'allah': 91,
#  'ki': 90,
#  'akparti': 84,
#  'artık': 84,
#  'öğretmen': 78,
#  'bekliyor': 72,
#  'dbdevletbahceli': 70,
#  'diye': 69,
#  'mı': 69,
#  'neden': 69,
#  'ekremimamoglu': 68,
#  'öğretmenler': 67,
#  'bakanım': 67,
#  'güzel': 66,
#  '15': 65,
#  'siz': 63,
#  'ziraat': 63,
#  'başkanım': 62,
#  'lütfen': 62,
# ...

# %%
focus_for_round2_keywords = ['görüşmelerine', 'komisyonunda', 'tbmm', 'neferleri', 'mustafadestici', 'anlayamadiniz', 'sevdası', 'siyaseti', 'faikoztrak', 'sülüüüü', 'müdürlüğüne', 'türkiyemizin', 'adice', 'örgütünün', 'pençekilit', 'çiftçilerimizle', 'ekmeğim', 'uyusturucudanda', 'tehdit', 'sevdasına', 'sözleşmelisi', 'hakkımız', 'parlementer', 'yakalım', 'tbmm’de', 'iyiparti5yaşında', 'teşkilat', 'sevdamız', 'etsuriyeli', 'sülooo', 'koalisyon', 'bırakınbu', 'işsizliğe', 'lutfuturkkan', 'başkanlığında', 'yıkım', 'başkonsolosumuz', 'eyy', 'alimahir', 'kadroya', 'muhattap', 'başkanımız', 'kılıçdaroğlu', 'veliagbaba', 'terör']
focus_for_round2_hashtags = ['genelaf', 'ziraatmüh15binatama', 'secime15binziraatmüh', 'ehliyetaffı', 'eyt', 'yüzyılınataması24kasımda', 'kasıma100binöğretmen', '112çmhyetektercihyetersiz', 'elektrikelektronikmüh3binkadro', 'yüzbinöğretmenmecliste', 'erdoğandan100binöğretmen', 'taşeronnedenbekliyor', 'iyiolankazansın', '15binziraatmilliekonomiye', 'vahitkirisci15binziraatmüh', 'tümtaşeronaayrımsızkadro', 'stajsskbaşlangıcıolsun', 'kislasizmakulbedelli', 'yhskaldirilsin', 'kılıçdaroğlunesöyledi', 'hbystaşeronkalmasın', 'fahriöğreticilerekadroşart', 'taşeronsuztürkiyei̇stiyoruz', 'genelafsebepleri', 'önlisanssosyalgüvenlik2binatama', 'kamuya5000mimar', 'özelleştirme4blileriunvaniylakadroya', 'emlakveemlakyönetimi', 'torbayasadayhs', '112açmyeçmhyakışır', 'bağkurtescilmağdurları', 'kahramanlarakadroverin', '112açmçmhi̇ledahagüçlü', 'taseronucubebirsistemdir', 'tbmm', 'laboratuvaraadilatama', 'haritakadastroteknikerleriatanamıyor', 'cbsağlıkyönetimibeşbinkadro', 'onlisanspomeme15bin', 'takkedüştükelgörüldü', 'eyt99sonuolsun', 'devlettetaşeronolurmu', 'devlettetaşeronolurmu', 'puançokkadroyok', 'uzmçvşabayramolsun', 'bagkurtescilmagdurlari', 'mebdenedebiyata10bin', 'pomeme15binkontenjan', 'eythakkınıtami̇stiyor', 'bagkurtescilimiyoksayma', 'insaatmühendisleriatamabekliyor', 'stajsskbaslangıcıbekliyor', 'taşeronaacilçözüm', 'askerlikborclanması', 'taşeronahayırkadroyaevet', 'taşeronradyolojiyekadro', 'sözleşmelimemuraşartsızkadro', 'pomem15binistiyor', 'oyum2020kpssye', 'diyanet4300yedekmuejdebekliyor', 'uzmçvşlarınsözleşmeçilesi', 'türkiyeyüzyılı', 'köyokullarinakadroluata', 'taşeronunsabrıbitti', 'cekehapiscezasıkalksın', 'verilensözlertutulsunartık', 'meclisteteröristi̇stemiyoruz', 'kamudışıkadroya', 'muhalefetstajıkonuş', 'imaraffıistiyoruz', 'stajmeclisetakıldı', 'sicilaffı', 'şartsızkadro', 'denklikaffımeclisegelsin', 'yabancıuyrukluasistanhekimler', 'inşaatmühendislerikamuya', 'jeolojimüh1000atama', 'kadrodaöncelikuzmçvşa', 'kamuyagıdamühşart', '2022kpssiptaledilsin', 'seçime100binöğretmen', 'emeklilikteyaşatakılaniar', 'iyiparti5yaşında']
focus_for_round2_mentions = ['kilicdarogluk', 'enginozkoc', 'umitozdag', '06melihgokcek', 'veliagbaba', 'mansuryavas06', 'yavuzagiraliog', 'meral_aksener', 'tcaytunciray', 'chp_istanbulil', 'herkesicinchp', 'enginaltaychp', 'alimahir', 'chpmuratbakan', 'vedatbilgn', 'mehmetozhaseki', 'LutfuTurkkan', 'ekrem_imamoglu', 'iyiparti', 'fahrettinaltun', 'ikalin1', 'faikoztrak', 'mustafa_destici', 'dbdevletbahceli', 'varank', 'vedatbilgn', 'akaraismailoglu', 'bybekirbozdag', 'nureddinnebati']

# %%
from unicode_tr import unicode_tr
zort = []

for hashtag in focus_for_round2_hashtags:
    zort.append(hashtag.lower().translate(str.maketrans('', '', "!\"$%&()*+-/<=>?[\]^`{|}~")))
print(zort)
# Out:
# ['genelaf', 'ziraatmüh15binatama', 'secime15binziraatmüh', 'ehliyetaffı', 'eyt', 'yüzyılınataması24kasımda', 'kasıma100binöğretmen', '112çmhyetektercihyetersiz', 'elektrikelektronikmüh3binkadro', 'yüzbinöğretmenmecliste', 'erdoğandan100binöğretmen', 'taşeronnedenbekliyor', 'iyiolankazansın', '15binziraatmilliekonomiye', 'vahitkirisci15binziraatmüh', 'tümtaşeronaayrımsızkadro', 'stajsskbaşlangıcıolsun', 'kislasizmakulbedelli', 'yhskaldirilsin', 'kılıçdaroğlunesöyledi', 'hbystaşeronkalmasın', 'fahriöğreticilerekadroşart', 'taşeronsuztürkiyei̇stiyoruz', 'genelafsebepleri', 'önlisanssosyalgüvenlik2binatama', 'kamuya5000mimar', 'özelleştirme4blileriunvaniylakadroya', 'emlakveemlakyönetimi', 'torbayasadayhs', '112açmyeçmhyakışır', 'bağkurtescilmağdurları', 'kahramanlarakadroverin', '112açmçmhi̇ledahagüçlü', 'taseronucubebirsistemdir', 'tbmm', 'laboratuvaraadilatama', 'haritakadastroteknikerleriatanamıyor', 'cbsağlıkyönetimibeşbinkadro', 'onlisanspomeme15bin', 'takkedüştükelgörüldü', 'eyt99
# ...

# %%
import string
import operator
import gzip
import json
import numpy as np
import pandas as pd

i = 0
totalTweets = 0
uniqueHashtags = {}
uniqueMentions = {}

with gzip.open("data/tweet_metadata.jsons.gz", "rb") as f:
    for line in f:

        tweet = json.loads(line)
        
        if tweet['id_str'] in all_tweets:
            print("match")
            totalTweets += 1

            if len(tweet['entities']) != 0:
                if len(tweet['entities']['hashtags']) != 0:
                    hashtags = tweet['entities']['hashtags']
                    for hashtag in hashtags:
                        hashtag = hashtag['text']
                        if hashtag not in uniqueHashtags.keys():
                            uniqueHashtags[hashtag] = 1
                        else:
                            uniqueHashtags[hashtag] += 1
                if len(tweet['entities']['user_mentions']) != 0:
                    mentions = tweet['entities']['user_mentions']
                    for mention in mentions:
                        mention = mention['screen_name']
                        if mention not in uniqueMentions.keys():
                            uniqueMentions[mention] = 1
                        else:
                            uniqueMentions[mention] += 1

        i += 1
        if i % 100 == 0:
            print(i)
            
sortedUniqueHashtags = dict(sorted(uniqueHashtags.items(), key=operator.itemgetter(1), reverse=True))
sortedUniqueMentions = dict(sorted(uniqueMentions.items(), key=operator.itemgetter(1), reverse=True))

print("\nTotal Tweets:")
print(totalTweets)
# Out:
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# 100
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# 200
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# 300
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# match
# 400
# ...

# %%
sortedUniqueHashtags
# Out:
# {'GenelAf': 15,
#  'ZiraatMüh15BinAtama': 11,
#  'Secime15BinZiraatMüh': 10,
#  'EhliyetAffı': 7,
#  'Vakıfbank': 7,
#  'EYT': 6,
#  'YüzyılınAtaması24Kasımda': 6,
#  'Kasıma100BinÖğretmen': 6,
#  '112ÇMHyeTekTercihYetersiz': 5,
#  'ElektrikElektronikMüh3binKadro': 5,
#  'YüzbinÖğretmenMecliste': 5,
#  'Erdoğandan100BinÖğretmen': 5,
#  'TaşeronNedenBekliyor': 5,
#  'iyiolankazansın': 4,
#  'AlpNavruz': 4,
#  '15BinZiraatMilliEkonomiye': 4,
#  'VahitKirisci15BinZiraatMüh': 4,
#  'TümTaşeronaAyrımsızKadro': 4,
#  'StajSskBaşlangıcıOlsun': 4,
#  'KislasizMakulBedelli': 4,
#  'YHSKALDIRILSIN': 3,
#  'KılıçdaroğluNeSöyledi': 3,
#  'HBYSTaşeronKalmasın': 3,
#  'FahriÖğreticilereKadroŞart': 3,
#  'TaşeronsuzTürkiyeİstiyoruz': 3,
#  'GenelAfSebepleri': 3,
#  'önlisanssosyalgüvenlik2binatama': 3,
#  'Kamuya5000mimar': 3,
#  'Özelleştirme4BlileriUnvaniylaKadroya': 3,
#  'emlakveemlakyönetimi': 3,
#  'TorbaYasadaYHS': 3,
#  '112AÇMyeÇMHyakışır': 3,
#  'HandeErçel': 3,
#  'DibYedeklereİlan': 2,
# ...

# %%
total = 0
for key, value in sortedUniqueHashtags.items():
    total += value
print(total)
# Out:
# 738

# %%
sortedUniqueMentions
# Out:
# {'RTErdogan': 696,
#  'kilicdarogluk': 244,
#  'meral_aksener': 199,
#  'drfahrettinkoca': 169,
#  'suleymansoylu': 160,
#  'umitozdag': 124,
#  'vedatbilgn': 110,
#  'Akparti': 84,
#  'dbdevletbahceli': 74,
#  'ekrem_imamoglu': 68,
#  'tcbestepe': 50,
#  'TCAytunCiray': 48,
#  'Mustafa_Destici': 48,
#  'tcmeb': 46,
#  'varank': 42,
#  'alimahir': 40,
#  'celebimehmeta': 39,
#  '06melihgokcek': 38,
#  'DpGultekinUysal': 37,
#  'akaraismailoglu': 36,
#  'bybekirbozdag': 35,
#  'herkesicinCHP': 35,
#  'VahitKirisci': 35,
#  'tele1comtr': 33,
#  'alpayozalan35': 33,
#  'osmannnurika': 33,
#  'dfikrisaglar': 33,
#  'eczozgurozel': 32,
#  'NureddinNebati': 31,
#  'TC_icisleri': 30,
#  'fethigurer': 30,
#  'enginozkoc': 29,
#  'yilmaztunc': 29,
#  'Ahmet_Davutoglu': 28,
#  'EmineErdogan': 28,
#  'AvOzlemZengin': 28,
#  'fuatoktay': 28,
#  'NumanKurtulmus': 27,
#  'mansuryavas06': 26,
#  'DIBAliErbas': 26,
#  'omerrcelik': 26,
#  'iyiparti': 26,
#  'BY': 26,
#  'veliagbaba': 25,
# ...

# %%
import csv

all_tweets_round3 = []

with open("evaluation-round3-tweet.csv", 'r') as file:
    csvreader = csv.reader(file)
    for row in csvreader:
        all_tweets_round3.append(row[0])

print("Total Tweets:", len(all_tweets_round3))                          
print(all_tweets_round3)
# Out:
# Total Tweets: 5000
# ...

# %%
import csv

all_tweets_round3 = []

with open("evaluation-round3-tweet.csv", 'r') as file:
    csvreader = csv.reader(file)
    for row in csvreader:
        all_tweets_round3.append(row[0])
        
import string
import operator
import gzip
import json
import numpy as np
import pandas as pd
from unicode_tr import unicode_tr

i = 0
totalTweets = 0
uniqueWords = {}
totalWords = 0

with gzip.open("data/tweet_metadata.jsons.gz", "rb") as f:
    for line in f:

        tweet = json.loads(line)
        if tweet['id_str'] in all_tweets_round3:
            # print("match")
            totalTweets += 1
            text = unicode_tr(tweet['text'].translate(str.maketrans('', '', "!\"$%&()*+-/<=>?[\]^`{|}~")).translate(str.maketrans(' ', ' ', ".,;:")))
            words = text.lower().split()
            for word in words:
                totalWords += 1
                unique_word = word
                if unique_word not in uniqueWords.keys():
                    uniqueWords[unique_word] = 1
                else:
                    uniqueWords[unique_word] += 1

        i += 1
        if i % 100 == 0:
            print(i)
            
sortedUniqueWords = dict(sorted(uniqueWords.items(), key=operator.itemgetter(1), reverse=True))

uniqueWordsDf = pd.DataFrame.from_dict(sortedUniqueWords, orient ='index')

print("\nTotal Tweets:")
print(totalTweets)

print("\nTotal Words:")
print(totalWords)

# uniqueWordsDf

with open("uniqueWordsRound3.json", "w") as outfile:
    json.dump(sortedUniqueWords, outfile, ensure_ascii=False)
# Out:
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800
# 10900
# 11000
# 11100
# 11200
# 11300
# 11400
# 11500
# 11600
# 11700
# 11800
# 11900
# 12000
# 12100
# 12200
# 12300
# 12400
# 12500
# 12600
# 12700
# 12800
# 12900
# 13000
# 13100
# 13200
# 13300
# 13400
# 13500
# 13600
# 13700
# 13800
# ...

# %%
focus_for_round3_keywords = ['sayın', 'atama', 'kadro', 'istiyoruz', 'bakanım', 'vekilim', 'adil', 'başkanım', 'af', 'oy', 'adalet', 'taşeron', 'staj', 'istihdam', 'khk', 'akp', 'mağdur', 'pkk', 'cumhurbaşkanımız', 'sesimizi', 'bekliyoruz', 'cumhurbaşkanım', 'reis', 'başkanı', 'kamu', 'tayyip', 'istiyoruz.', 'bekliyoruz.', 'sn.', 'terör', 'ceza', 'seçim', 'başkan', 'parti', 'eyt', 'sözleşmeli', 'müjde', 'mahkum', 'siyasi', 'kadroya', 'mağduru', 'yüzüncüyıla', 'mansur', 'hdp', 'terörist', 'istiyoruz.…', 'başkanımız', 'atamanın', 'ediyoruz.…', 'cezalar', 'örgütü', 'muhalefet', 'bakanı', 'sesimiz', 'vekil', 'cumhur', 'fetö', 'erdoğanaffı', 'mağdurları', 'ihlali', 'iftira', 'müjdesi', 'mağduriyeti', 'alımı', 'atama…', 'özdağ', 'cumhuriyetimizin', 'yüzüncüyılda', 'affettürkiyem', 'genelaf', 'istifa', 'demokrasi', 'seninleyiz', 'adli', 'hakaret', 'büyüklerimiz', 'istemiyoruz', 'iktidara', "sgk'ye", 'bakanımız', 'desteğiniz', 'ekpss', 'müjdeli', 'bizimdevletimiz', 'unutmayın', 'ittifakı', 'zam', 'partisi', 'akparti', 'türkiyem', 'seçimöncesi', 'cumhurbaşkanım,', 'talebimiz', 'kgm', 'hdpkk', 'sesimize', 'kpssden', 'yazıklar', 'affetmelidir', 'borçlanma', 'helalestirmekten', 'adaletli', 'sn.cumhurbaskanımızın', 'atanmak', 'fetöcü', 'mağdurlarının']
focus_for_round3_mentions = ['kilicdarogluk', 'meral_aksener', 'meral_aksener', 'drfahrettinkoca', 'suleymansoylu', 'umitozdag', 'vedatbilgn', 'ekrem_imamoglu', 'dbdevletbahceli', 'akparti', 'tcbestepe', 'mustafa_destici', 'tcmeb', 'tcaytunciray', '06melihgokcek', 'alpayozalan35', 'akaraismailoglu', 'alimahir', 'bybekirbozdag', 'herkesicinchp', 'celebimehmeta', 'osmannnurika', 'varank', 'fethigurer', 'eczozgurozel', 'dıbalierbas', 'vahitkirisci', 'nureddinnebati', 'lutfuturkkan', 'avozlemzengin', 'dfikrisaglar', 'iyiparti', 'arzuerdemdb', 'deryayanikashb', 'dpgultekinuysal', 'mahirunal', 'alibabacan', 'enginozkoc', 'fahrettinaltun', 'fuatoktay', 'numankurtulmus', 'yilmaztunc', 'omerrcelik', 'veliagbaba', 'tc_icisleri', 'faikoztrak', 'mansuryavas06', 'ikalin1', 'ahmet_davutoglu', 'vekilince', 'mhp_bilgi', 'cenginyurt52', 'by', 'avabdullahguler', 'csgbakanligi', 'mvhuseyinyildiz', 'yavuzagiraliog', 'bbpgenelmerkez', '_cevdetyilmaz', 'adalet_bakanlik', 'emrullahisler', 'murat_kurum', 'jsarieroglu', 'seferaycan', 'akbasogluemin', 'hdpdemirtas', 'olcaykilavuz', 'hdpgenelmerkezi', 'sgirgin48tbmm', 'orhanssumer', 'canan_kaftanci', 'bakisimsekmhp', 'aefakibaba', 'bulenttufenkci', 'samiltayyar27', 'avhamzadag', 'zaferpartisi', 'nacicinisli', 'tanjuozcanchp', 'av_burcu03', 'umitdikbayir', 'hayati_yazici', 'mehmedmus', 'serkantopalchp', 'ısliyendr', 'yildirimkaya40', 'belginuygur10', 'dr_sozdemir', 'avantmen33', 'erkanakcay45', 'mkulunk', 'akpartimalatya', 'akgencmalatya', 'eczburhan', 'tbmmresmi', 'aliihsanyavuz54', 'csbgovtr', 'mustafasentop', 'drsoysal', '_aliyalcin_', 'yildizfeti', 'turanbulent', 'kasapoglu', 'erenerdemnet', 'akkadın_malatya', 'emniyetgm', 'gergerliogluof', 'senolsunat', 'fahrettinyokus', 'mhptbmmgrubu', 'ayhanbarut01', 'barisyarkadas', 'ayyildirim1', 'avorhankırcalı', 'stajmadurlarıd1', 'mehmetnuriersoy', 'avsabriozturk', 'devapartisi', 'gurseltekin34', 'erkankandemir', 'aysekesir', 'drfahrettinkoca…', 'emine_gozgec16', 'mehmetersoy57', 's_turpcu', 'mt_goksu', 'mevlutcavusoglu', 'hasandogan', 'kilicdarogluk…', 'seyit_torun', 'mstanrikulu', 'sezaitemelli', 'vedatbilgn…', '55erhanusta', 'ramazancan0071', 'akpartiistanbul', 'yilmaz_ismet58', 'ikoncuk', 'mehmetozhaseki', 't_karamollaoglu', 'tc_icisleri…', 'matillakaya', 'mzyensevkin', 'dursunatas38', 'nacicinisli…', 'bbahadirerdem']
focus_for_round3_hashtags = ['genelaf', 'yüzyılınataması24kasımda', 'ziraatmüh15binatama', 'ehliyetaffı', 'taşeronnedenbekliyor', '112çmhyetektercihyetersiz', 'elektrikelektronikmüh3binkadro', 'erdoğandan100binöğretmen', 'secime15binziraatmüh']

# %%
import numpy as np
political_hashtags = ['abdullahbasci', 'adem_taskaya', 'ahmet_davutoglu', 'ahmet_erozan', 'akburak', 'ali_oztunc', 'alibabacan', 'alidincercolak', 'aliihsanyavuz54', 'alipulcu', 'av_ebrugunay', 'avhamzadag', 'avidrissahin', 'avozlemzengin', 'avtolgaakalin', 'avunzileyuksel', 'ayangurol', 'ayhanseferustun', 'ayhanturkz', 'ayseacar_b', 'aysekesir', 'bartusoral', 'bayirfikret', 'bbahadirerdem', 'bbbozarslan', 'bdalgin', 'birolaydemir15', 'bkusoglu', 'bmustafagozel', 'bulenttezcanchp', 'buyukataman', 'by', 'c_karlitekin', 'cezmi_polat', 'dbdevletbahceli', 'dogandemir41', 'dogasanlioglu', 'draslanyaman', 'dromerileri', 'drsametmenguc', 'e_semihyalcin', 'efkanala', 'elifesendeva', 'emin_ekmen', 'erginsadullah', 'erkankandemir', 'eyupkadirinan', 'faikoztrak', 'fatihsahin', 'feleknasuca', 'feramuzustun', 'feridunbilgin64', 'feridunyildiz', 'figenyuksekdag', 'gamzeilgezdi', 'garopaylan', 'gokcegokcen', 'guleryuzmahfuz', 'gulizarbicer', 'hasankaraltr', 'hatipoglupaysun', 'hayati_yazici', 'hbb_ciftcioglu', 'hdpdemirtas', 'helunfirat', 'ifarukaksu', 'ilknur_birol', 'ismail_turk55', 'jsarieroglu', 'kamilaydinmhp', 'kaptmustafacan', 'karakayamevlut', 'kerimrota', 'kilicdarogluk', 'kocaktukenmez', 'korayaydintr', 'lalekarabiyik', 'leylasahinusta', 'lutfusahsuvar', 'medeniylmz', 'mehmetozhaseki', 'meral_aksener', 'meraldanis', 'metinergun48', 'mithatsancarr', 'mnedimyamali', 'muharremerkek17', 'muratozgur2001', 'musaproglu', 'mustafaergen_', 'mustafamente', 'mustafaucak07', 'myeneroglu', 'nazlisedavural', 'numankurtulmus', 'nurettincanikli', 'oguzksalici', 'omerrcelik', 'onursaladiguzel', 'pervinbuldan', 'prfdrfilizkilic', 'profbilgeyilmaz', 'ridvanuz17', 'rizvanogluevrim', 'rterdogan', 'sadirdurmaz', 'sagaltun', 'salimensarioglu', 'sanemoktar', 'saruhanoluc', 'saziyekose59', 'sedattimur161', 'selcukozdag', 'selimtemurci', 'selinsayekboke', 'semasilkin', 'senolsunat', 'serapprof', 'serkanozcan1', 'sevdagultuncer', 'sevincatabay', 'seyit_torun', 'seyityucel06', 'sonmeznaci', 'sultanozcan38', 'tayiptemel', 'tckayalak', 'tmrosmanagaoglu', 'torunkani', 'tugrulk_zaferp', 'tuncerbakirhan', 'ugur_poyraz', 'ugurbaturr', 'ulviyonter', 'umitdikbayir', 'umitozdag', 'umitozlale', 'umityardim1961', 'umutdede16', 'vedatdemiroz', 'vekilince', 'velisacilik', 'yasaryldrmmhp', 'yaseminbilgel1', 'yildizfeti', 'yukseltaskinn', 'yunusparım', '06melihgokcek', '55erhanusta', 'LutfuTurkkan', '_aliyalcin_', '_cevdetyilmaz', '_fatihsahin', 'abdulhamitgul', 'abdullahbasci', 'adalet_bakanlik', 'adem__taskaya', 'aefakibaba', 'ahmet_davutoglu', 'ahmet_erozan', 'ahmetedip_ugur', 'akaraismailoglu', 'akbasogluemin', 'akburak', 'akgencistanbul', 'akgenclikgm', 'akgencmalatya', 'akkadingm', 'akkadın_malatya', 'akparti', 'akpartiistanbul', 'akpartimalatya', 'ali_oztunc', 'alibabacan', 'alidincercolak', 'aliihsanyavuz54', 'alimahir', 'alipulcu', 'alpayozalan35', 'arzuerdemdb', 'av_burcu03', 'av_ebrugunay', 'avabdullahguler', 'avantmen33', 'avhamzadag', 'avidrissahin', 'avorhankırcalı', 'avozlemzengin', 'avsabriozturk', 'avtolgaakalin', 'avunzileyuksel', 'ayangurol', 'ayhanbarut01', 'ayhanseferustun', 'ayhanturkz', 'ayseacar_b', 'aysekesir', 'ayyildirim1', 'bakanguler', 'bakisimsekmhp', 'barisyarkadas', 'bartusoral', 'bayirfikret', 'bbahadirerdem', 'bbbozarslan', 'bbpgenelmerkez', 'bdalgin', 'bekirpakdemirli', 'belginuygur10', 'birolaydemir15', 'birolaydinsp', 'bkusoglu', 'bmustafagozel', 'bulent_arinc', 'bulenttezcanchp', 'bulenttufenkci', 'buyukataman', 'by', 'bybekirbozdag', 'c_karlitekin', 'canan_kaftanci', 'celebimehmeta', 'cenginyurt52', 'cezmi_polat', 'chp_istanbulil', 'chpgencistanbul', 'chpgenclikgm', 'chpmuratbakan', 'ck_samsun', 'csbgovtr', 'csgbakanligi', 'csgbfarukcelik', 'dbdevletbahceli', 'deryayanikashb', 'devapartisi', 'dfikrisaglar', 'dogandemir41', 'dogasanlioglu', 'dpgultekinuysal', 'dr_demircan', 'dr_sozdemir', 'draslanyaman', 'drfahrettinkoca', 'drfahrettinkoca…', 'dromerileri', 'drsametmenguc', 'drsoysal', 'dursunatas38', 'dıbalierbas', 'e_semihyalcin', 'eczburhan', 'eczozgurozel', 'efkanala', 'egemenbagis', 'ekrem_imamoglu', 'elifesendeva', 'emin_ekmen', 'emine_gozgec16', 'emniyetankara', 'emniyetgm', 'emrullahisler', 'enginaltaychp', 'enginozkoc', 'erdoganbayraktr', 'erenerdemnet', 'erginsadullah', 'erkanakcay45', 'erkankandemir', 'eyupkadirinan', 'fahrettinaltun', 'fahrettinyokus', 'faikoztrak', 'fatmasahin', 'fatmasahin_aspb', 'feleknasuca', 'feramuzustun', 'feridunbilgin64', 'feridunyildiz', 'fethigurer', 'figenyuksekdag', 'fuatoktay', 'gamzeilgezdi', 'garopaylan', 'gazianteppolis', 'gergerliogluof', 'gokcegokcen_', 'guleryuzmahfuz', 'gulizarbicer', 'gurseltekin34', 'hakan_cavusoglu', 'hasandogan', 'hasankaraltr', 'hatipoglupaysun', 'hayati_yazici', 'hbb_ciftcioglu', 'hdpdemirtas', 'hdpgenelmerkezi', 'helunfirat', 'herkesicinchp', 'ifarukaksu', 'ikalin1', 'ikoncuk', 'ilknur_birol', 'ismail_turk55', 'istanbul_egm', 'iyiparti', 'jsarieroglu', 'kadir_topbas', 'kamilaydinmhp', 'kaptmustafacan', 'karakayamevlut', 'kartalakgenclik', 'kasapoglu', 'kerimrota', 'kilicdarogluk', 'kilicdarogluk…', 'kocaeliemniyeti', 'kocaktukenmez', 'korayaydintr', 'lalekarabiyik', 'leylasahinusta', 'lutfusahsuvar', 'lutfuturkkan', 'mahirunal', 'mansuryavas06', 'matillakaya', 'medeniylmz', 'mehmedmus', 'mehmetersoy57', 'mehmetnuriersoy', 'mehmetozhaseki', 'memetsimsek', 'meral_aksener', 'meraldanis', 'metinergun48', 'mevlutcavusoglu', 'mhp_bilgi', 'mhptbmmgrubu', 'mithatsancarr', 'mkulunk', 'mnedimyamali', 'mstanrikulu', 'mt_goksu', 'muezzinogludr', 'muharremerkek17', 'murat_kurum', 'muratozgur2001', 'musaproglu', 'mustafa_destici', 'mustafaergen_', 'mustafamente', 'mustafasentop', 'mustafaucak07', 'mvhuseyinyildiz', 'myeneroglu', 'mzyensevkin', 'nacicinisli', 'nacicinisli…', 'nazlisedavural', 'numankurtulmus', 'nureddinnebati', 'nurettincanikli', 'oguzksalici', 'olcaykilavuz', 'omerrcelik', 'onursaladiguzel', 'orhanssumer', 'osmannnurika', 'pekcan', 'pervinbuldan', 'prfdrfilizkilic', 'profbilgeyilmaz', 'ramazancan0071', 'ridvanuz17', 'rizvanogluevrim', 'rterdogan', 's_turpcu', 'saadethukuk', 'saadetpartisi', 'sadirdurmaz', 'sagaltun', 'saglikbakanligi', 'salimensarioglu', 'samiltayyar27', 'sanemoktar', 'saruhanoluc', 'saziyekose59', 'sedattimur161', 'seferaycan', 'selcukozdag', 'selimtemurci', 'selinsayekboke', 'semasilkin', 'senolsunat', 'serapprof', 'serkanozcan1', 'serkantopalchp', 'sevdagultuncer', 'sevincatabay', 'seyit_torun', 'seyityucel06', 'sezaitemelli', 'sgirgin48tbmm', 'sonmeznaci', 'stajmadurlarıd1', 'suatkilic', 'suleymansoylu', 'suleymansoyluhayati_yazici', 'sultanozcan38', 't_karamollaoglu', 'tanjuozcanchp', 'tayiptemel', 'tbmmresmi', 'tc_disisleri', 'tc_icisleri', 'tc_icisleri…', 'tcaytunciray', 'tcbestepe', 'tckayalak', 'tcmeb', 'tcsavunma', 'tmrosmanagaoglu', 'torunkani', 'tugrulk_zaferp', 'tuncerbakirhan', 'tuncsoyer', 'turanbulent', 'ugur__poyraz', 'ugurbaturr', 'ulviyonter', 'umitdikbayir', 'umitozdag', 'umitozlale', 'umityardim1961', 'umutdede16', 'vahitkirisci', 'varank', 'vedatbilgn', 'vedatbilgn…', 'vedatdemiroz', 'vekilince', 'veliagbaba', 'velisacilik', 'veyseleroglu', 'yasaryldrmmhp', 'yaseminbilgel1', 'yavuzagiraliog', 'yildirimkaya40', 'yildizfeti', 'yilmaz_ismet58', 'yilmaztunc', 'yukseltaskinn', 'yunusparim', 'zaferpartisi', 'ısliyendr']
political_hashtags = np.unique(political_hashtags)
print(list(political_hashtags))
# Out:
# ['06melihgokcek', '55erhanusta', 'LutfuTurkkan', '_aliyalcin_', '_cevdetyilmaz', '_fatihsahin', 'abdulhamitgul', 'abdullahbasci', 'adalet_bakanlik', 'adem__taskaya', 'adem_taskaya', 'aefakibaba', 'ahmet_davutoglu', 'ahmet_erozan', 'ahmetedip_ugur', 'akaraismailoglu', 'akbasogluemin', 'akburak', 'akgencistanbul', 'akgenclikgm', 'akgencmalatya', 'akkadingm', 'akkadın_malatya', 'akparti', 'akpartiistanbul', 'akpartimalatya', 'ali_oztunc', 'alibabacan', 'alidincercolak', 'aliihsanyavuz54', 'alimahir', 'alipulcu', 'alpayozalan35', 'arzuerdemdb', 'av_burcu03', 'av_ebrugunay', 'avabdullahguler', 'avantmen33', 'avhamzadag', 'avidrissahin', 'avorhankırcalı', 'avozlemzengin', 'avsabriozturk', 'avtolgaakalin', 'avunzileyuksel', 'ayangurol', 'ayhanbarut01', 'ayhanseferustun', 'ayhanturkz', 'ayseacar_b', 'aysekesir', 'ayyildirim1', 'bakanguler', 'bakisimsekmhp', 'barisyarkadas', 'bartusoral', 'bayirfikret', 'bbahadirerdem', 'bbbozarslan', 'bbpgenelmerkez', 'bdalgin', 'bekirpakdemirli', 'belginuyg
# ...

# %%
political_keywords = ['imamoğlu', 'sayın', 'atama', 'kadro', 'istiyoruz', 'bakanım', 'vekilim', 'adil', 'başkanım', 'af', 'oy', 'adalet', 'taşeron', 'staj', 'istihdam', 'khk', 'akp', 'mağdur', 'pkk', 'cumhurbaşkanımız', 'sesimizi', 'bekliyoruz', 'cumhurbaşkanım', 'reis', 'başkanı', 'kamu', 'tayyip', 'istiyoruz', 'bekliyoruz', 'sn.', 'terör', 'ceza', 'seçim', 'başkan', 'parti', 'eyt', 'sözleşmeli', 'müjde', 'mahkum', 'siyasi', 'kadroya', 'mağduru', 'yüzüncüyıla', 'mansur', 'hdp', 'terörist', 'istiyoruz…', 'başkanımız', 'atamanın', 'ediyoruz…', 'cezalar', 'örgütü', 'muhalefet', 'bakanı', 'sesimiz', 'vekil', 'cumhur', 'fetö', 'erdoğanaffı', 'mağdurları', 'ihlali', 'iftira', 'müjdesi', 'mağduriyeti', 'alımı', 'atama…', 'özdağ', 'cumhuriyetimizin', 'yüzüncüyılda', 'affettürkiyem', 'genelaf', 'istifa', 'demokrasi', 'seninleyiz', 'adli', 'hakaret', 'büyüklerimiz', 'istemiyoruz', 'iktidara', "sgk'ye", 'bakanımız', 'desteğiniz', 'ekpss', 'müjdeli', 'bizimdevletimiz', 'unutmayın', 'ittifakı', 'zam', 'partisi', 'akparti', 'türkiyem', 'seçimöncesi', 'cumhurbaşkanım', 'talebimiz', 'kgm', 'hdpkk', 'sesimize', 'kpssden', 'yazıklar', 'affetmelidir', 'borçlanma', 'helalestirmekten', 'adaletli', 'sn' , 'cumhurbaskanımızın', 'atanmak', 'fetöcü', 'mağdurlarının', 'adalet', 'adil', 'ak parti', 'akp', 'akparti', 'atama', 'atamaları', 'ataması', 'atamavakti', 'babacan', 'bakanlık', 'bakanlığı', 'başkan', 'başkanlık', 'başkanı', 'başkanım', 'başkanımız', 'belediye', 'belediyesi', 'büyükşehir', 'chp', 'chpli', 'cumhurbaşkanlığı', 'cumhurbaşkanı', 'cumhurbaşkanım', 'cumhurbaşkanımız', 'cumhuriyet', 'cumhuriyetçi', 'deva', 'ekonomi', 'enflasyon', 'erdoğan', 'eyt', 'eşitlik', 'fetö', 'güvenlik', 'hakları', 'hdp', 'hukuk', 'ibb', 'imamoğlu', 'ittifakı', 'kadro', 'khk', 'kılıçdaroğlu', 'mahkeme', 'mağdur', 'mhp', 'milletvekili', 'oy', 'parti', 'partisi', 'pkk', 'recep', 'reis', 'reisimiz', 'sayın', 'sağlık', 'seçim', 'siyaset', 'sn', 'soylu', 'soysuz', 'tayyip', 'taşeron', 'terör', 'terörist', 'özgürlük']
political_mentions = ['06melihgokcek', '55erhanusta', '_aliyalcin_', '_cevdetyilmaz', '_fatihsahin', 'abdulhamitgul', 'abdullahbasci', 'adalet_bakanlik', 'adem__taskaya', 'aefakibaba', 'ahmet_davutoglu', 'ahmet_erozan', 'ahmetedip_ugur', 'akaraismailoglu', 'akbasogluemin', 'akburak', 'akgencistanbul', 'akgenclikgm', 'akgencmalatya', 'akkadingm', 'akkadın_malatya', 'akparti', 'akpartiistanbul', 'akpartimalatya', 'ali_oztunc', 'alibabacan', 'alidincercolak', 'aliihsanyavuz54', 'alimahir', 'alipulcu', 'alpayozalan35', 'arzuerdemdb', 'av_burcu03', 'av_ebrugunay', 'avabdullahguler', 'avantmen33', 'avhamzadag', 'avidrissahin', 'avorhankırcalı', 'avozlemzengin', 'avsabriozturk', 'avtolgaakalin', 'avunzileyuksel', 'ayangurol', 'ayhanbarut01', 'ayhanseferustun', 'ayhanturkz', 'ayseacar_b', 'aysekesir', 'ayyildirim1', 'bakanguler', 'bakisimsekmhp', 'barisyarkadas', 'bartusoral', 'bayirfikret', 'bbahadirerdem', 'bbbozarslan', 'bbpgenelmerkez', 'bdalgin', 'bekirpakdemirli', 'belginuygur10', 'birolaydemir15', 'birolaydinsp', 'bkusoglu', 'bmustafagozel', 'bulent_arinc', 'bulenttezcanchp', 'bulenttufenkci', 'buyukataman', 'by', 'bybekirbozdag', 'c_karlitekin', 'canan_kaftanci', 'celebimehmeta', 'cenginyurt52', 'cezmi_polat', 'chpgencistanbul', 'chpgenclikgm', 'ck_samsun', 'csbgovtr', 'csgbakanligi', 'csgbfarukcelik', 'dbdevletbahceli', 'deryayanikashb', 'devapartisi', 'dfikrisaglar', 'dogandemir41', 'dogasanlioglu', 'dpgultekinuysal', 'dr_demircan', 'dr_sozdemir', 'draslanyaman', 'drfahrettinkoca', 'drfahrettinkoca…', 'dromerileri', 'drsametmenguc', 'drsoysal', 'dursunatas38', 'dıbalierbas', 'e_semihyalcin', 'eczburhan', 'eczozgurozel', 'efkanala', 'egemenbagis', 'ekrem_imamoglu', 'elifesendeva', 'emin_ekmen', 'emine_gozgec16', 'emniyetankara', 'emniyetgm', 'emrullahisler', 'enginozkoc', 'erdoganbayraktr', 'erenerdemnet', 'erginsadullah', 'erkanakcay45', 'erkankandemir', 'eyupkadirinan', 'fahrettinaltun', 'fahrettinyokus', 'faikoztrak', 'fatmasahin', 'fatmasahin_aspb', 'feleknasuca', 'feramuzustun', 'feridunbilgin64', 'feridunyildiz', 'fethigurer', 'figenyuksekdag', 'fuatoktay', 'gamzeilgezdi', 'garopaylan', 'gazianteppolis', 'gergerliogluof', 'gokcegokcen_', 'guleryuzmahfuz', 'gulizarbicer', 'gurseltekin34', 'hakan_cavusoglu', 'hasandogan', 'hasankaraltr', 'hatipoglupaysun', 'hayati_yazici', 'hbb_ciftcioglu', 'hdpdemirtas', 'hdpgenelmerkezi', 'helunfirat', 'herkesicinchp', 'ifarukaksu', 'ikalin1', 'ikoncuk', 'ilknur_birol', 'ismail_turk55', 'istanbul_egm', 'iyiparti', 'jsarieroglu', 'kadir_topbas', 'kamilaydinmhp', 'kaptmustafacan', 'karakayamevlut', 'kartalakgenclik', 'kasapoglu', 'kerimrota', 'kilicdarogluk', 'kilicdarogluk…', 'kocaeliemniyeti', 'kocaktukenmez', 'korayaydintr', 'lalekarabiyik', 'leylasahinusta', 'lutfusahsuvar', 'lutfuturkkan', 'mahirunal', 'mansuryavas06', 'matillakaya', 'medeniylmz', 'mehmedmus', 'mehmetersoy57', 'mehmetnuriersoy', 'mehmetozhaseki', 'memetsimsek', 'meral_aksener', 'meraldanis', 'metinergun48', 'mevlutcavusoglu', 'mhp_bilgi', 'mhptbmmgrubu', 'mithatsancarr', 'mkulunk', 'mnedimyamali', 'mstanrikulu', 'mt_goksu', 'muezzinogludr', 'muharremerkek17', 'murat_kurum', 'muratozgur2001', 'musaproglu', 'mustafa_destici', 'mustafaergen_', 'mustafamente', 'mustafasentop', 'mustafaucak07', 'mvhuseyinyildiz', 'myeneroglu', 'mzyensevkin', 'nacicinisli', 'nacicinisli…', 'nazlisedavural', 'numankurtulmus', 'nureddinnebati', 'nurettincanikli', 'oguzksalici', 'olcaykilavuz', 'omerrcelik', 'onursaladiguzel', 'orhanssumer', 'osmannnurika', 'pekcan', 'pervinbuldan', 'prfdrfilizkilic', 'profbilgeyilmaz', 'ramazancan0071', 'ridvanuz17', 'rizvanogluevrim', 'rterdogan', 's_turpcu', 'saadethukuk', 'saadetpartisi', 'sadirdurmaz', 'sagaltun', 'saglikbakanligi', 'salimensarioglu', 'samiltayyar27', 'sanemoktar', 'saruhanoluc', 'saziyekose59', 'sedattimur161', 'seferaycan', 'selcukozdag', 'selimtemurci', 'selinsayekboke', 'semasilkin', 'senolsunat', 'serapprof', 'serkanozcan1', 'serkantopalchp', 'sevdagultuncer', 'sevincatabay', 'seyit_torun', 'seyityucel06', 'sezaitemelli', 'sgirgin48tbmm', 'sonmeznaci', 'stajmadurlarıd1', 'suatkilic', 'suleymansoylu', 'suleymansoyluhayati_yazici', 'sultanozcan38', 't_karamollaoglu', 'tanjuozcanchp', 'tayiptemel', 'tbmmresmi', 'tc_disisleri', 'tc_icisleri', 'tc_icisleri…', 'tcaytunciray', 'tcbestepe', 'tckayalak', 'tcmeb', 'tcsavunma', 'tmrosmanagaoglu', 'torunkani', 'tugrulk_zaferp', 'tuncerbakirhan', 'tuncsoyer', 'turanbulent', 'ugur__poyraz', 'ugurbaturr', 'ulviyonter', 'umitdikbayir', 'umitozdag', 'umitozlale', 'umityardim1961', 'umutdede16', 'vahitkirisci', 'varank', 'vedatbilgn', 'vedatbilgn…', 'vedatdemiroz', 'vekilince', 'veliagbaba', 'velisacilik', 'veyseleroglu', 'yasaryldrmmhp', 'yaseminbilgel1', 'yavuzagiraliog', 'yildirimkaya40', 'yildizfeti', 'yilmaz_ismet58', 'yilmaztunc', 'yukseltaskinn', 'yunusparim', 'zaferpartisi', 'ısliyendr']
political_hashtags = ['100yılaffı', '10aralıkdünyainsanhaklarıgünü', '10binkadro', '112açmyeacilçmhalımı', '112açmyeortaksızalım', '112açmyeçmhdenalım', '112açmçmhiledahagüçlü', '112çmhyetektercihyetersiz', '120bintaşeronbekliyor', '2000sonrasısgklıadaletistiyor', '2023yolundabiriz', '21yüzyıldataşeronolmasın', '5binatamaradyolojiye', 'adaletaffı', 'amerikanınçocuklarısınız', 'aralıksonuşartsızeyt', 'aralıktakadroocaktaeş', 'atamayapmaönlisansıbekle', 'bağkurtescilmağdurları', 'belediyeşirketikadroya', 'benimoyum100binatamaya', 'bütcedetaşeronvarmı', 'bütçeden100binöğretmen', 'cb15binziraatmüh', 'cbingilizce10binatama', 'cumhurücretliögrtkadro', 'cumhurücretliöğrtkadro', 'dib15binalımhakkımız', 'diyetisyen245ekarşı', 'ehliyetaffi', 'ehliyetaffı', 'elektrikelektronikmüh3binkadro', 'emekleriyasalaratakılanlar', 'emeklilikteyaşatakılanlar', 'emeklilkteyasatakılanlar', 'engelliyeatamamüjdesi', 'erdoğandan100binöğretmen', 'eyt', 'eyt99sonuhakkımız', 'eytdepremmağdurları', 'eytdeyaşkoşulunahayır', 'eytlininsabrıtaştı', 'geleceğizyinegeleceğiz', 'geliyorgelmekteolan', 'genelaf', 'güvenlikkorucularınsesiniduyun', 'herkesekadrouzmçvşayokmu', 'ikinciyüzyılaçağrı', 'imarbarışıgüncellensin', 'içişleriyedekleratansın', 'kabinedetaşerondaolsun', 'kabinesözlmyekadro', 'kadrohaktır', 'kadroiçinmeclise', 'kadrovekili̇mamlarınhakkı', 'kamudakadrosuzkalmasın', 'kamui̇şçisikadrosuzkalmasın', 'kapımagelmeoyi̇çin', 'kasapogludestekver', 'kasıma100binöğretmen', 'kasımdaadil100binatama', 'kgm1000atama', 'kgmmüşavirekadrohaktır', 'kimlertaşeronişçisi', 'kurtulmakistiyoruz', 'kılıçdaroğlunesöyledi', 'kıslasızmakulbedelli', 'lisetıbbisekretere0kadro', 'meblisegeneliaf', 'memurögrtverimliistihdam', 'müjdezamanıgelmedimi', 'ogretmenlersusmayacak', 'patronsağlıkbakanıi̇stemiyoruz', 'pomemeyedekcagri', 'sansüryasasınahayır', 'sartlıeytyehayır', 'sağlısollutokatlasoylu', 'sağlığavaröğretmeneyok', 'sonsözüeytsöyler', 'stajaadalet', 'stajsskbaslangiciolsun', 'stajsskbaşlangıcıolsun', 'stajyerinselamıvar', 'stajyermuhalefetdiyor', 'stajyoksaoydayok', 'sözleşmelimemuraşartsızkadro', 'sıradastajolsun', 'tarikatvecemaatlerkapatilsin', 'tarikatvecemaatlerkapatılsın', 'taşeronaşartsızkadro', 'taşerondaadaletliolun', 'taşeronmeclisegelmeli', 'taşeronnedenbekliyor', 'taşeronradyolojikadrobekliyor', 'taşerontorbaya', 'taşeronucubebirsistemdir', 'taşeronunsabrıkalmadı', 'tbmmvekilimamlarakadro', 'tcyüzyılıücretliögrtkadro', 'tümtaşeronlarakadro', 'türkiyeyüzyılı', 'uzmançavuşlarakadro', 'uzmançavuşlarkadroya', 'vatansavunanakadro', 'vergideadaletbelediyedekadro', 'veterinerhekimler5000atamaistiyor', 'yanındayızimamoğlu', 'yüzbinöğretmeninsesi', 'yüzyılınataması24kasımda', 'yüzüncüyıla100binatama', 'ziraate15bin6limasa', 'zorunluemeklilikkaldırılsın', 'zorunluemeklilikzulümdür', 'ögretmeneenaz25bin', 'önlisanssosyalgüvenlik4binatama', 'özdağadokunma', 'öğretmeneenaz25bin', 'öğretmeneyüzde100zam', 'ümitözdağ', 'şanınayakışır', 'şartlıeytyehayır', 'şehadetesaskadrohaktır', 'şehirhastanelerinekadro']

# %%
hadibakim = ['RTErdogan', 'BY', 'NumanKurtulmus', 'Hayati_Yazici', 'erkankandemir', 'aliihsanyavuz54', 'avhamzadag', 'efkanala', 'jsarieroglu', 'mehmetozhaseki', 'nurettincanikli', 'AvOzlemZengin', 'leylasahinusta', 'vedatdemiroz', 'DrOmerileri', 'omerrcelik', 'fatihsahin', 'aysekesir', 'eyupkadirinan', 'kilicdarogluk', 'ali_oztunc', 'bkusoglu', 'bulenttezcanchp', 'faikoztrak', 'gamzeilgezdi', 'GokceGokcen', 'GulizarBicer', 'lalekarabiyik', 'muharremerkek17', 'oguzksalici', 'onursaladiguzel', 'selinsayekboke', 'seyit_torun', 'yukseltaskinn', 'alibabacan', 'birolaydemir15', 'yaseminbilgel1', 'bdalgin', 'emin_ekmen', 'mustafaergen_', 'erginsadullah', 'elifesendeva', 'helunfirat', 'hasankaraltr', 'c_karlitekin', 'sanemoktar', 'hatipoglupaysun', 'rizvanogluevrim', 'avidrissahin', 'dogasanlioglu', 'mustafaucak07', 'nazlisedavural', 'myeneroglu', 'medeniylmz', 'Ahmet_Davutoglu', 'mnedimyamali', 'SelimTemurci', 'AyhanSeferUSTUN', 'dogandemir41', 'FeridunBilgin64', 'selcukozdag', 'abdullahbasci', 'kerimrota', 'mustafamente', 'SerapProf', 'AliPulcu', 'umityardim1961', 'SemaSilkin', 'Hbb_Ciftcioglu', 'BMustafaGozel', 'feramuzustun', 'torunkani', 'serkanozcan1', 'hdpdemirtas', 'figenyuksekdag', 'pervinbuldan', 'mithatsancarr', 'ayseacar_b', 'av_ebrugunay', 'Feleknasuca', 'GaroPaylan', 'SaruhanOluc', 'ilknur_Birol', 'GuleryuzMahfuz', 'meraldanis', 'musaproglu', 'sonmeznaci', 'drsametmenguc', 'sultanozcan38', 'saziyekose59', 'TayipTemel', 'tuncerbakirhan', 'UmutDede16', 'velisacilik', 'YunusPARIM', 'meral_aksener', 'korayaydintr', 'UGUR_POYRAZ', 'UmitDikbayir', 'BBahadirErdem', 'senolsunat', 'Ahmet_Erozan', 'ridvanuz17', 'SalimEnsarioglu', 'MetinErgun48', 'ProfBilgeYilmaz', 'avtolgaakalin', 'UmitOzlale', 'SevincAtabay', 'avunzileyuksel', 'Akburak', 'vekilince', 'dbdevletbahceli', 'E_SemihYalcin', 'yildizfeti', 'ifarukaksu', 'KarakayaMevlut', 'kamilaydinmhp', 'UlviYonter', 'sadirdurmaz', 'yasaryldrmmhp', 'buyukataman', 'prfdrfilizkilic', 'tmrosmanagaoglu', 'bbbozarslan', 'umitozdag', 'adem_taskaya', 'alidincercolak', 'sevdagultuncer', 'bartusoral', 'ayhanturkz', 'cezmi_polat', 'tugrulk_zaferp', 'draslanyaman', 'feridunyildiz', 'BayirFikret', 'AyanGurol', 'ismail_turk55', 'KocakTukenmez', 'lutfusahsuvar', 'muratozgur2001', 'kaptmustafacan', 'sagaltun', 'sedattimur161', 'seyityucel06', 'TCKayalak', 'ugurbaturr']

from unicode_tr import unicode_tr
yenilist = []
for ent in hadibakim:
    zuhuqu = unicode_tr(ent.translate(str.maketrans('', '', "\"$%&()*+-/<=>[\]^`{|}~")).translate(str.maketrans(' ', ' ', ".,;:!?")))
    zuhuqu = zuhuqu.lower()
    yenilist.append(zuhuqu)

print(sorted(list(yenilist)))
# Out:
# ['abdullahbasci', 'adem_taskaya', 'ahmet_davutoglu', 'ahmet_erozan', 'akburak', 'ali_oztunc', 'alibabacan', 'alidincercolak', 'aliihsanyavuz54', 'alipulcu', 'av_ebrugunay', 'avhamzadag', 'avidrissahin', 'avozlemzengin', 'avtolgaakalin', 'avunzileyuksel', 'ayangurol', 'ayhanseferustun', 'ayhanturkz', 'ayseacar_b', 'aysekesir', 'bartusoral', 'bayirfikret', 'bbahadirerdem', 'bbbozarslan', 'bdalgin', 'birolaydemir15', 'bkusoglu', 'bmustafagozel', 'bulenttezcanchp', 'buyukataman', 'by', 'c_karlitekin', 'cezmi_polat', 'dbdevletbahceli', 'dogandemir41', 'dogasanlioglu', 'draslanyaman', 'dromerileri', 'drsametmenguc', 'e_semihyalcin', 'efkanala', 'elifesendeva', 'emin_ekmen', 'erginsadullah', 'erkankandemir', 'eyupkadirinan', 'faikoztrak', 'fatihsahin', 'feleknasuca', 'feramuzustun', 'feridunbilgin64', 'feridunyildiz', 'figenyuksekdag', 'gamzeilgezdi', 'garopaylan', 'gokcegokcen', 'guleryuzmahfuz', 'gulizarbicer', 'hasankaraltr', 'hatipoglupaysun', 'hayati_yazici', 'hbb_ciftcioglu', 'hdpdemi
# ...
